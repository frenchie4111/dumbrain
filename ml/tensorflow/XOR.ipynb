# %% [markdown]
# # XOR
#
# Train a toy model to predict the XOR function

# %%
import numpy as np
import tensorflow as tf

# %%
samples = np.array( [
    [ 0, 0, 0 ],
    [ 1, 1, 0 ],
    [ 0, 1, 1 ],
    [ 1, 0, 1 ]
], dtype=float )

Y = samples[ :, 0:1  ]
X = samples[ :, 1: ]

# %%
x = tf.placeholder( tf.float32, shape=( 4, 2 ) )
y = tf.placeholder( tf.float32, shape=( 4, 1 ) )

l1_weights = tf.Variable( tf.random_uniform( ( 2, 5 ), -1, 1 ) )
l1_biases = tf.Variable( tf.zeros( ( 5 ) ) )

l1 = tf.sigmoid( tf.matmul( x, l1_weights ) + l1_biases )

l2_weights = tf.Variable( tf.random_uniform( ( 5, 1 ), -1, 1 ) )
l2_biases = tf.Variable( tf.zeros( ( 1 ) ) )

output = tf.sigmoid( tf.matmul( l1, l2_weights ) + l2_biases )

loss = tf.reduce_mean(tf.square(Y - output))

train_step = tf.train.GradientDescentOptimizer( 0.01 ).minimize( loss )

init = tf.global_variables_initializer()

sess = tf.Session()
sess.run( init )

for train_sessions in range( 200000 ):
    feed_dict = { x: X, y: Y }
    _ = sess.run( train_step, feed_dict=feed_dict )
    if ( train_sessions ) % 5000 == 0:
        print( '----', train_sessions, ':', sess.run( ( loss, output ), feed_dict=feed_dict ) )

final_outputs = sess.run( output, feed_dict={ x: X, y: Y } )
print( final_outputs )
# Out:
# ---- 0 : (0.27066168, array([[0.61337763],
#        [0.6665295 ],
#        [0.6721121 ],
#        [0.62121594]], dtype=float32))
# ---- 5000 : (0.24930868, array([[0.4711402 ],
#        [0.5181107 ],
#        [0.52708334],
#        [0.48499763]], dtype=float32))
# ---- 10000 : (0.24810663, array([[0.4667103 ],
#        [0.5168134 ],
#        [0.5296121 ],
#        [0.48946136]], dtype=float32))
# ---- 15000 : (0.245867, array([[0.45841694],
#        [0.518719  ],
#        [0.53364235],
#        [0.49313077]], dtype=float32))
# ---- 20000 : (0.24152157, array([[0.44411296],
#        [0.52470416],
#        [0.53923815],
#        [0.4978386 ]], dtype=float32))
# ---- 25000 : (0.23373684, array([[0.42092976],
#        [0.53616756],
#        [0.54626864],
#        [0.5058183 ]], dtype=float32))
# ---- 30000 : (0.22121608, array([[0.3857621 ],
#        [0.5549461 ],
#        [0.55434287],
#        [0.5197053 ]], dtype=float32))
# ---- 35000 : (0.20326771, array([[0.33957285],
#        [0.5821319 ],
#        [0.5590843 ],
#        [0.54111856]], dtype=float32))
# ---- 40000 : (0.1802463, array([[0.29181254],
#        [0.61502486],
#        [0.54901165],
#        [0.5684783 ]], dtype=float32))
# ---- 45000 : (0.15218832, array([[0.25192353],
#        [0.64989775],
#        [0.5142168 ],
#        [0.60213405]], dtype=float32))
# ---- 50000 : (0.11933943, array([[0.22038251],
#        [0.6867724 ],
#        [0.45440835],
#        [0.64759284]], dtype=float32))
# ---- 55000 : (0.086325645, array([[0.19196501],
#        [0.7276637 ],
#        [0.38158143],
#        [0.70220715]], dtype=float32))
# ---- 60000 : (0.059816495, array([[0.16447444],
#        [0.76910484],
#        [0.31372768],
#        [0.7540803 ]], dtype=float32))
# ---- 65000 : (0.04171768, array([[0.14019027],
#        [0.80499065],
#        [0.2598798 ],
#        [0.79591364]], dtype=float32))
# ---- 70000 : (0.030095529, array([[0.12062406],
#        [0.8332903 ],
#        [0.2196658 ],
#        [0.8274116 ]], dtype=float32))
# ---- 75000 : (0.022602065, array([[0.10543068],
#        [0.85497975],
#        [0.18979679],
#        [0.85087276]], dtype=float32))
# ---- 80000 : (0.017616734, array([[0.09364843],
#        [0.87167674],
#        [0.16722956],
#        [0.8686062 ]], dtype=float32))
# ---- 85000 : (0.014171036, array([[0.08438386],
#        [0.8847462 ],
#        [0.14976995],
#        [0.8823181 ]], dtype=float32))
# ---- 90000 : (0.011699961, array([[0.07696228],
#        [0.8951844 ],
#        [0.13593431],
#        [0.8931721 ]], dtype=float32))
# ---- 95000 : (0.009869274, array([[0.07090888],
#        [0.90368015],
#        [0.12473406],
#        [0.9019545 ]], dtype=float32))
# ---- 100000 : (0.008473373, array([[0.0658831 ],
#        [0.91072   ],
#        [0.11548416],
#        [0.90919584]], dtype=float32))
# ---- 105000 : (0.0073827486, array([[0.06164461],
#        [0.9166473 ],
#        [0.10772388],
#        [0.915272  ]], dtype=float32))
# ---- 110000 : (0.0065132114, array([[0.05802648],
#        [0.92169887],
#        [0.10111804],
#        [0.92043966]], dtype=float32))
# ---- 115000 : (0.0058063176, array([[0.05489885],
#        [0.92607206],
#        [0.09542321],
#        [0.924897  ]], dtype=float32))
# ---- 120000 : (0.005223374, array([[0.05216379],
#        [0.92988265],
#        [0.09045876],
#        [0.9287736 ]], dtype=float32))
# ---- 125000 : (0.004735576, array([[0.04975125],
#        [0.9332347 ],
#        [0.08608937],
#        [0.9321905 ]], dtype=float32))
# ---- 130000 : (0.00432276, array([[0.04760849],
#        [0.9362169 ],
#        [0.08221481],
#        [0.9352164 ]], dtype=float32))
# ---- 135000 : (0.003969449, array([[0.04569218],
#        [0.93888724],
#        [0.0787535 ],
#        [0.93792635]], dtype=float32))
# ---- 140000 : (0.0036646875, array([[0.04395926],
#        [0.94128114],
#        [0.07563557],
#        [0.94035363]], dtype=float32))
# ---- 145000 : (0.0033988475, array([[0.04239487],
#        [0.9434583 ],
#        [0.07281431],
#        [0.9425615 ]], dtype=float32))
# ---- 150000 : (0.0031657342, array([[0.0409652 ],
#        [0.9454304 ],
#        [0.07024466],
#        [0.94456863]], dtype=float32))
# ---- 155000 : (0.002959635, array([[0.03965081],
#        [0.94724655],
#        [0.06789462],
#        [0.94639266]], dtype=float32))
# ---- 160000 : (0.0027769734, array([[0.03844633],
#        [0.94889915],
#        [0.06574007],
#        [0.94807005]], dtype=float32))
# ---- 165000 : (0.0026130052, array([[0.03734418],
#        [0.9504356 ],
#        [0.06374783],
#        [0.9496312 ]], dtype=float32))
# ---- 170000 : (0.002465949, array([[0.03630383],
#        [0.95185375],
#        [0.06191358],
#        [0.9510666 ]], dtype=float32))
# ---- 175000 : (0.002333083, array([[0.03535836],
#        [0.9531725 ],
#        [0.06019821],
#        [0.95240295]], dtype=float32))
# ---- 180000 : (0.0022130315, array([[0.03446496],
#        [0.9544126 ],
#        [0.05862154],
#        [0.9536363 ]], dtype=float32))
# ---- 185000 : (0.0021035883, array([[0.03363872],
#        [0.9555464 ],
#        [0.05713038],
#        [0.9548028 ]], dtype=float32))
# ---- 190000 : (0.0020032483, array([[0.0328581 ],
#        [0.95661604],
#        [0.0557289 ],
#        [0.9558926 ]], dtype=float32))
# ---- 195000 : (0.0019113886, array([[0.03211122],
#        [0.9576395 ],
#        [0.05443141],
#        [0.95690435]], dtype=float32))
# [[0.03143054]
#  [0.95857775]
#  [0.05320129]
#  [0.95786107]]

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier

from dumbrain.ml.kaggle.download import download
from dumbrain.lib import cleaners

# %matplotlib inline

# %%
data_files = download( 'house-prices-advanced-regression-techniques' )
files = list( map( lambda file: 'data/' + file, data_files ) )

# %%
test_file, desc_file, train_file, sample_file = files

# %%
train_data = pd.read_csv( train_file )

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
def describe( name, file=desc_file ):
    """
    Helper function to describe any type or value from the description file
    """
    with open( desc_file, 'r' ) as file:
        lines = file.read()
        for line in lines.split( '\n' ):
            line = line.strip().replace( '\t', ': ' )
            if name in line:
                return line

describe( 'AllPub' )
# Out:
# 'AllPub: All public Utilities (E,G,W,& S)'

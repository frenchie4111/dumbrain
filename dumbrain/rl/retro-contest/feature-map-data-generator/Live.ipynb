# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import retro
import scipy.misc
import matplotlib.pyplot as plt
import os
import numpy as np
import time
import cv2 as cv

env = None

from EightBitTemplateMatcher import EightBitTemplateMatcher

# %%
sonic_dir = 'data/sonic2/sonic'
sonic_files = os.listdir( sonic_dir )
sonic_files.sort()
sonics = [ scipy.misc.imread( os.path.join( sonic_dir, sonic_file ), mode='RGBA' ) for sonic_file in sonic_files ]

eight_bit_matcher = EightBitTemplateMatcher( sonics )
# Out:
# /home/mike/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.

# %%
if env is None:
    env = retro.make(game='SonicTheHedgehog2-Genesis', state='EmeraldHillZone.Act1')
_ = env.reset()

# %%
previous_sonic_position = None

for i in range( 1000 ):
    action = env.action_space.sample()
    action[ 7 ] = 1
    frame, reward, done, info = env.step( action )
    env.render()

    frame = frame.copy()
    results = eight_bit_matcher.matchTemplate( frame, previous=previous_sonic_position )

    previous_sonic_position = ( results[ 1 ], results[ 2 ] )

    print( previous_sonic_position )
    
#     cv.rectangle( frame, results[ 1 ], results[ 2 ], 255, 2 )

#     plt.subplots()
#     plt.imshow( frame )
#     plt.subplots()
#     plt.imshow( sonics[ results[ 3 ] ] )
#     plt.pause( 0.00001 )
    
    if done:
        env.reset()
# Out:
# 80 77 0 0 80 77 107 119
# ((80, 77), (107, 119))
# (80, 77)
# 5 5 72 75 80 77 107 119
# ((80, 77), (107, 119))
# (80, 77)
# 5 5 72 75 80 77 107 119
# ((80, 77), (107, 119))
# (80, 77)
# 5 5 72 75 80 77 107 119
# ((80, 77), (107, 119))
# (80, 77)
# 5 5 72 75 80 77 107 119
# ((80, 77), (107, 119))
# (80, 77)
# 5 5 72 75 80 77 107 119
# ((80, 77), (107, 119))
# (80, 77)
# 8 5 72 75 83 77 109 122
# ((83, 77), (109, 122))
# (83, 77)
# 3 4 72 78 81 76 110 121
# ((81, 76), (110, 121))
# (81, 76)
# 4 6 71 76 80 77 107 119
# ((80, 77), (107, 119))
# (80, 77)
# 5 5 72 75 80 77 107 119
# ((80, 77), (107, 119))
# (80, 77)
# 5 5 72 75 80 77 107 119
# ((80, 77), (107, 119))
# (80, 77)
# 8 5 72 75 83 77 109 122
# ((83, 77), (109, 122))
# (83, 77)
# 3 14 72 78 81 86 110 111
# ((81, 86), (110, 111))
# (81, 86)
# 5 1 81 76 81 82 110 111
# ((81, 82), (110, 111))
# (81, 82)
# 5 1 77 76 81 78 110 111
# ((81, 78), (110, 111))
# (81, 78)
# 5 1 73 76 81 74 110 111
# ((81, 74), (110, 111))
# (81, 74)
# 5 2 69 76 81 71 111 111
# ((81, 71), (111, 111))
# (81, 71)
# 5 2 66 76 81 68 111 111
# ((81, 68), (111, 111))
# (81, 68)
# ((111, 0), (141, 138))
# (111, 0)
# ((111, 0), (141, 138))
# (111, 0)
# ((111, 0), (141, 138))
# (111, 0)
# ((111, 0), (141, 138))
# (111, 0)
# ((111, 0), (141, 138))
# (111, 0)
# ((111, 0), (141, 138))
# (111, 0)
# ((111, 0), (141, 138))
# (111, 0)
# ((111, 0), (141, 138))
# (111, 0)
# ((111, 0), (141, 138))
# (111, 0)
# 84 54 0 0 84 54 114 114
# ((84, 54), (114, 114))
# (84, 54)
# 6 5 49 79 85 54 114 115
# ((85, 54), (114, 115))
# (85, 54)
# 6 5 49 80 86 54 115 116
# ((86, 54), (115, 116))
# (86, 54)
# ((86, 54), (115, 116))
# (86, 54)
# 6 5 49 81 87 54 116 117
# ((87, 54), (116, 117))
# (87, 54)
# 5 5 49 82 87 54 117 117
# ((87, 54), (117, 117))
# (87, 54)
# 5 5 49 82 87 54 117 117
# ((87, 54), (117, 117))
# (87, 54)
# 6 6 49 82 88 55 118 118
# ((88, 55), (118, 118))
# (88, 55)
# 6 6 50 83 89 56 119 119
# ((89, 56), (119, 119))
# (89, 56)
# 6 7 51 84 90 58 120 119
# ((90, 58), (120, 119))
# (90, 58)
# 6 6 53 85 91 59 121 120
# ((91, 59), (121, 120))
# (91, 59)
# 6 7 54 86 92 61 122 121
# ((92, 61), (122, 121))
# (92, 61)
# 6 6 56 87 93 62 123 122
# ((93, 62), (123, 122))
# (93, 62)
# 6 6 57 88 94 63 124 124
# ((94, 63), (124, 124))
# (94, 63)
# 6 7 58 89 95 65 125 125
# ((95, 65), (125, 125))
# (95, 65)
# 6 8 60 90 96 68 126 126
# ((96, 68), (126, 126))
# (96, 68)
# 6 7 63 91 97 70 127 127
# ((97, 70), (127, 127))
# (97, 70)
# 7 8 65 92 99 73 128 129
# ((99, 73), (128, 129))
# (99, 73)
# 6 8 68 94 100 76 129 130
# ((100, 76), (129, 130))
# (100, 76)
# 6 8 71 95 101 79 130 131
# ((101, 79), (130, 131))
# (101, 79)
# 6 9 74 96 102 83 131 132
# ((102, 83), (131, 132))
# (102, 83)
# 7 8 78 97 104 86 134 134
# ((104, 86), (134, 134))
# (104, 86)
# 107 77 0 0 107 77 133 146
# ((107, 77), (133, 146))
# (107, 77)
# 4 4 72 102 106 76 135 146
# ((106, 76), (135, 146))
# (106, 76)
# 7 5 71 101 108 76 137 148
# ((108, 76), (137, 148))
# (108, 76)
# 6 5 71 103 109 76 138 149
# ((109, 76), (138, 149))
# (109, 76)
# 6 5 71 104 110 76 139 150
# ((110, 76), (139, 150))
# (110, 76)
# 7 5 71 105 112 76 141 152
# ((112, 76), (141, 152))
# (112, 76)
# 6 5 71 107 113 76 142 153
# ((113, 76), (142, 153))
# (113, 76)
# 6 5 71 108 114 76 143 154
# ((114, 76), (143, 154))
# (114, 76)
# 112 75 0 0 112 75 151 152
# ((112, 75), (151, 152))
# (112, 75)
# 6 5 70 107 113 75 152 153
# ((113, 75), (152, 153))
# (113, 75)
# 7 5 70 108 115 75 154 155
# ((115, 75), (154, 155))
# (115, 75)
# 6 5 70 110 116 75 155 156
# ((116, 75), (155, 156))
# (116, 75)
# 6 5 70 111 117 75 156 157
# ((117, 75), (156, 157))
# (117, 75)
# 6 5 70 112 118 75 157 158
# ((118, 75), (157, 158))
# (118, 75)
# 6 5 70 113 119 75 158 159
# ((119, 75), (158, 159))
# (119, 75)
# 5 6 70 114 119 76 158 158
# ((119, 76), (158, 158))
# (119, 76)
# 7 5 71 114 121 76 160 160
# ((121, 76), (160, 160))
# (121, 76)
# 6 5 71 116 122 76 161 161
# ((122, 76), (161, 161))
# (122, 76)
# 6 5 71 117 123 76 162 162
# ((123, 76), (162, 162))
# (123, 76)
# 6 5 71 118 124 76 163 163
# ((124, 76), (163, 163))
# (124, 76)
# 9 15 71 119 128 86 157 158
# ((128, 86), (157, 158))
# (128, 86)
# 6 1 81 123 129 82 158 159
# ((129, 82), (158, 159))
# (129, 82)
# 6 1 77 124 130 78 159 160
# ((130, 78), (159, 160))
# (130, 78)
# 5 2 73 125 130 75 160 160
# ((130, 75), (160, 160))
# (130, 75)
# 6 1 70 125 131 71 161 161
# ((131, 71), (161, 161))
# (131, 71)
# 6 2 66 126 132 68 162 162
# ((132, 68), (162, 162))
# (132, 68)
# 6 2 63 127 133 65 163 162
# ((133, 65), (163, 162))
# (133, 65)
# 6 3 60 128 134 63 164 163
# ((134, 63), (164, 163))
# (134, 63)
# 6 2 58 129 135 60 165 164
# ((135, 60), (165, 164))
# (135, 60)
# 7 3 55 130 137 58 167 167
# ((137, 58), (167, 167))
# (137, 58)
# 6 3 53 132 138 56 168 168
# ((138, 56), (168, 168))
# (138, 56)
# 6 3 51 133 139 54 169 169
# ((139, 54), (169, 169))
# (139, 54)
# 7 5 49 134 141 54 170 171
# ((141, 54), (170, 171))
# (141, 54)
# 6 5 49 136 142 54 171 172
# ((142, 54), (171, 172))
# (142, 54)
# 6 5 49 137 143 54 172 173
# ((143, 54), (172, 173))
# (143, 54)
# 5 5 49 138 143 54 173 173
# ((143, 54), (173, 173))
# (143, 54)
# 6 5 49 138 144 54 174 174
# ((144, 54), (174, 174))
# (144, 54)
# 6 5 49 139 145 54 175 175
# ((145, 54), (175, 175))
# (145, 54)
# 5 6 49 140 145 55 175 174
# ((145, 55), (175, 174))
# (145, 55)
# 5 5 50 140 145 55 175 174
# ((145, 55), (175, 174))
# (145, 55)
# 5 6 50 140 145 56 175 174
# ((145, 56), (175, 174))
# (145, 56)
# 5 4 51 140 145 55 175 175
# ((145, 55), (175, 175))
# (145, 55)
# 5 6 50 140 145 56 175 175
# ((145, 56), (175, 175))
# (145, 56)
# 5 5 51 140 145 56 175 175
# ((145, 56), (175, 175))
# (145, 56)
# 5 6 51 140 145 57 174 175
# ((145, 57), (174, 175))
# (145, 57)
# 5 7 52 140 145 59 174 175
# ((145, 59), (174, 175))
# (145, 59)
# 5 6 54 140 145 60 174 175
# ((145, 60), (174, 175))
# (145, 60)
# 5 7 55 140 145 62 175 175
# ((145, 62), (175, 175))
# (145, 62)
# 5 7 57 140 145 64 175 175
# ((145, 64), (175, 175))
# (145, 64)
# 5 7 59 140 145 66 175 175
# ((145, 66), (175, 175))
# (145, 66)
# 5 7 61 140 145 68 175 174
# ((145, 68), (175, 174))
# (145, 68)
# 5 8 63 140 145 71 175 174
# ((145, 71), (175, 174))
# (145, 71)
# 5 8 66 140 145 74 175 174
# ((145, 74), (175, 174))
# (145, 74)
# 5 8 69 140 145 77 175 175
# ((145, 77), (175, 175))
# (145, 77)
# 5 8 72 140 145 80 175 175
# ((145, 80), (175, 175))
# (145, 80)
# 5 8 75 140 145 83 175 175
# ((145, 83), (175, 175))
# (145, 83)
# 6 9 78 140 146 87 175 176
# ((146, 87), (175, 176))
# (146, 87)
# 5 9 82 141 146 91 175 176
# ((146, 91), (175, 176))
# (146, 91)
# 5 9 86 141 146 95 175 176
# ((146, 95), (175, 176))
# (146, 95)
# 147 83 0 0 147 83 173 186
# ((147, 83), (173, 186))
# (147, 83)
# 145 76 0 0 145 76 174 185
# ((145, 76), (174, 185))
# (145, 76)
# 5 15 71 140 145 86 174 175
# ((145, 86), (174, 175))
# (145, 86)
# 145 80 0 0 145 80 174 175
# ((145, 80), (174, 175))
# (145, 80)
# 5 1 75 140 145 76 174 175
# ((145, 76), (174, 175))
# (145, 76)
# 5 4 71 140 145 75 174 172
# ((145, 75), (174, 172))
# (145, 75)
# 5 1 70 140 145 71 174 172
# ((145, 71), (174, 172))
# (145, 71)
# 5 2 66 140 145 68 174 172
# ((145, 68), (174, 172))
# (145, 68)
# 145 62 0 0 145 62 175 174
# ((145, 62), (175, 174))
# (145, 62)
# 5 2 57 140 145 59 175 174
# ((145, 59), (175, 174))
# (145, 59)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-26bed0213607> in <module>()
#       8
#       9     frame = frame.copy()
# ---> 10     results = eight_bit_matcher.matchTemplate( frame, previous=previous_sonic_position )
#      11
#      12     previous_sonic_position = ( results[ 1 ], results[ 2 ] )
#
# ~/Programming/dumbrain/rl/retro-contest/feature-map-data-generator/TemplateMatcher.py in matchTemplate(self, frame, previous)
#      66                 start_time = time.clock()
#      67
# ---> 68                 results = cv.matchTemplate( search_frame, template, cv.TM_CCORR_NORMED, mask=mask )
#      69                 _, score, _, max_loc = cv.minMaxLoc( results )
#      70
#
# KeyboardInterrupt:
